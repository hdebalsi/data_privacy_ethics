# %%
import sklearn.datasets as skd
import pandas as pd

# %%
X, y = skd.make_friedman1(n_samples = 100, n_features = 15)
X = pd.DataFrame(X, columns = ["x" + str(i) for i in range(1, 16)])

# %%
X.head()
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# 0  0.481896  0.606095  0.693767  0.264511  0.211487  0.073827  0.195268
# 1  0.924313  0.515185  0.858773  0.664853  0.172442  0.181773  0.537968
# 2  0.587609  0.817583  0.689312  0.107605  0.755618  0.952442  0.139838
# 3  0.350369  0.313288  0.385745  0.182279  0.946721  0.241956  0.504062
# 4  0.380973  0.397731  0.597674  0.845242  0.475583  0.048190  0.698041
#
#          x8        x9       x10       x11       x12       x13       x14  \
# 0  0.233862  0.581954  0.892335  0.496067  0.332459  0.461146  0.543202
# 1  0.326459  0.544241  0.806105  0.004286  0.318118  0.855673  0.979725
# 2  0.526300  0.515712  0.019316  0.555218  0.090119  0.101767  0.238898
# 3  0.449593  0.489221  0.433347  0.812288  0.952986  0.713390  0.929820
# 4  0.032595  0.107107  0.299689  0.013310  0.844226  0.410764  0.777239
#
#         x15
# 0  0.759845
# 1  0.308512
# 2  0.961597
# 3  0.406004
# 4  0.668211
